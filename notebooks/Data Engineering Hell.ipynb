# %%
import pandas as pd

# %%
# !ls station_address_data
# Out:
# Berkeley.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_Berkeley.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_Lafayeette.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_LongBeach.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_Misc.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_SanBernadino.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_SouthSanFrancisco.csv
# Fri_Apr_30_16-52-23_2021-final_stations_addr_info-missed.csv
# Fri_Apr_30_16-52-23_2021-final_stations_addr_info-new.csv
# Fri_Apr_30_16-52-23_2021-final_stations_addr_info-old.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_Berkeley.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_Lafayeette.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_LongBeach.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_Misc.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_SanBernadino.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_SouthSanFrancisco.csv
# Lafayeette.csv
# Lafayette.csv
# LongBeach.csv
# Misc.csv
# SanBernadino.csv
# SouthSanFrancisco.csv
# Zcraper.csv
# full_unique_addreseses.csv
# ...

# %%
a = pd.read_csv('station_address_data/Fri_Apr_30_16-52-23_2021-final_stations_addr_info-missed.csv')

b = pd.read_csv('station_address_data/Fri_Apr_30_16-52-23_2021-final_stations_addr_info-old.csv')

# %%
combined = pd.concat([a,b])

# %%
combined[['latitude', 'longitude', 'address', 'hours-with-measurements', 'measurment-count', ]]
# Out:
#       latitude   longitude                                        address  \
# 0    37.600795 -122.391258               290 Broadway, Millbrae, CA 94030
# 1    37.603466 -122.394409         525 El Camino Real, Millbrae, CA 94030
# 2    37.609445 -122.401375        1375 El Camino Real, Millbrae, CA 94030
# 3    37.620550 -122.411508        333 El Camino Real, San Bruno, CA 94066
# 4    37.648739 -122.383097  500 E Jamie Ct, South San Francisco, CA 94080
# ..         ...         ...                                            ...
# 193  37.899269 -122.298414                           280 El Cerrito Plaza
# 194  37.655462 -122.400932                               250 Gateway Blvd
# 195  37.579749 -122.350650                                501 Primrose Rd
# 196  37.663411 -122.394875                          151 Oyster Point Blvd
# 197  37.806087 -122.267285                                1717 Webster St
#
#      hours-with-measurements  measurment-count
# ...

# %%
f = pd.read_csv('utilization_rates_data/Sat_May_1_15-04-25_2021_processed.csv')
# Out:
# /Library/Python/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
f.head()
# Out:
#    Unnamed: 0                       _id          time  \
# 0           0  607631c1fcfd04e161e08ddd  1.618359e+09
# 1           1  607631c1fcfd04e161e08dde  1.618359e+09
# 2           2  607632edfcfd04e161e08e1e  1.618359e+09
# 3           3  607632edfcfd04e161e08e1f  1.618359e+09
# 4           4  607632f9fcfd04e161e08e2b  1.618359e+09
#
#                    datetime connection_type available power_kwh  \
# 0  Tue Apr 13 17:05:10 2021         CHAdeMO       3/3     50 kW
 ('37.812568', '-122.264583'),
 ('37.8226285', '-122.25953909999998'),
 ('37.8391784', '-122.29276829999999'),
 ('37.839350399999994', '-122.29814329999999'),
 ('37.8556066', '-122.26024869999999'),
 ('37.8642141', '-122.3134533'),
 ('37.8683341', '-122.30067609999999'),
 ('37.873462599999996', '-122.30512659999998'),
 ('37.876104999999995', '-122.2952268'),
 ('37.898365000000005', '-122.3077125')]

# %%
lats = []
longs = []
for pair in coords:
    lats.append(pair[0])
    longs.append(pair[1])

# %%
pd.DataFrame({'latitude':lats, 'longitude':longs}).drop_duplicates().sort_values(['latitude', 'longitude'])
# Out:
#               latitude            longitude
# 0           33.7666633         -118.1841092
# 2    33.77247670000001          -118.191701
# 1           33.8022142         -118.1680387
# 190         37.4505321  -122.17915719999999
# 185         37.5547203         -122.3165489
# ..                 ...                  ...
# 112          37.988051         -122.0868513
# 113         37.9920555         -122.0877873
# 48          37.9945718         -122.1018517
# 139         38.6399398         -120.5279096
# 114         40.4475498          -80.0695135
#
# [225 rows x 2 columns]

# %%
combined.drop_duplicates(['latitude', 'longitude']).sort_values(['latitude', 'longitude'])
# Out:
#      Unnamed: 0                                 address  \
# 0             0  707 E Ocean Blvd, Long Beach, CA 90802
# 2             2       50 E 5th St, Long Beach, CA 90802
# 1             1  2475 Cherry Ave, Signal Hill, CA 90755
# 189          69                      525 El Camino Real
# 184          63                     1375 El Camino Real
# ..          ...                                     ...
# 111          80                          255 Glacier Dr
# 112          81                          1875 Arnold Dr
# 48           17                          1145 Arnold Dr
# 138         107                                    CA-4
# 113          82                     112 W. Prospetc Ave
#
#      hours-with-measurements  measurment-count  \
# 0                         24              5091
# 2                         24              3266
# 1                         24              3496
# 189                       17               675
# 184                       17              1012
# ...

# %%
# len(combined['mapped_addy'].unique())
# for addy in combined['mapped_addy']:
#     print(addy)
len(f['mapped_addy'].unique())
# Out:
# 275

# %%
collected = []
for c in combined['mapped_addy'].unique():
    if c in f['mapped_addy'].unique():
        collected.append(c)

# %%
flipped = []
for c in f['mapped_addy'].unique():
    if c in combined['mapped_addy'].unique():
        flipped.append(c)

# %%
len(collected)
# Out:
# 129

# %%
len(flipped)
# Out:
# 129

# %%
built = pd.DataFrame()
for addy in combined['mapped_addy']:
    retained = f[f['mapped_addy']==addy]
    built = pd.concat([built,retained])

# %%
df = pd.merge(left=built, right=combined, on='mapped_addy')

# %%
len(built['mapped_addy'].unique()), len(combined['mapped_addy'].unique()),
# Out:
# (129, 230)

# %%
print(df.columns, len(df))
df.head()
# Out:
# Index(['Unnamed: 0_x', 'Unnamed: 0.1', '_id', 'time', 'datetime',
#        'connection_type', 'available', 'power_kwh', 'address_x', 'day_of_week',
#        'day_of_week_num', 'month', 'date', 'hour', 'minutes', 'seconds',
#        'available_numerator', 'available_denominator', 'power_kwh_num',
#        'original_addy_x', 'mapped_addy', 'Unnamed: 0_y', 'address_y',
#        'hours-with-measurements', 'measurment-count', 'original_addy_y',
#        'source', 'latitude', 'longitude'],
#       dtype='object') 682886
#    Unnamed: 0_x  Unnamed: 0.1                       _id          time  \
# 0        481583           338  6076347dfcfd04e161e08f2f  1.618359e+09
# 1        481584           424  607634f5fcfd04e161e08f85  1.618359e+09
# 2        481585           510  6076356dfcfd04e161e08fdb  1.618360e+09
# 3        481586          2474  60764661fcfd04e161e09787  1.618364e+09
# 4        481587          2547  607646edfcfd04e161e097d0  1.618364e+09
#
# ...

# %%
station_cols = ['connection_type', 'power_kwh', 'power_kwh_num', 
              'mapped_addy', 'latitude', 'longitude',
               'available_denominator']
time_cols = ['day_of_week', 'day_of_week_num', 'month', 'date', 'hour', 'minutes',
       'seconds',]

## average all columns, while getting rid of time related columns
# drop time related columns since one station should have a single score regardless of time
# ignore charging stations that have no denominator
UR_by_stations_first_group = df.drop(time_cols, axis=1)[df['available_denominator'] != 0].groupby(by=station_cols).agg('mean').reset_index()

address_cols = ['mapped_addy', 'latitude', 'longitude']
UR_by_stations = UR_by_stations_first_group.groupby(address_cols).agg('sum').reset_index()
UR_by_stations.head()

UR_by_stations['availability_rate'] = UR_by_stations['available_numerator']/UR_by_stations['available_denominator']

UR_by_stations['utilization_rate'] = 1-UR_by_stations['availability_rate']

UR_by_stations['total_output_kwh'] = UR_by_stations['power_kwh_num']*UR_by_stations['utilization_rate']

UR_by_stations['utilization_numerator'] = UR_by_stations['available_denominator']*UR_by_stations['utilization_rate']

# %%
kept_cols = ['mapped_addy', 'latitude', 'longitude', 'power_kwh_num', 'available_denominator', 'available_numerator', 'availability_rate', 'utilization_rate', 'total_output_kwh', 'utilization_numerator']
UR_by_stations[kept_cols].to_csv('utilization_rates_data/final_113.csv')

# %%
# !ls data
# Out:
# X_matrix_april_12.csv                full_weekly_timeseries_with_POIs.csv
# address_mapper.csv                   grocery-stores-QueryResult.csv
# final_matrix.csv                     official_aggregated_datasets.csv

# %%
final_matrix = pd.read_csv('data/final_matrix.csv').drop(['Unnamed: 0', '0'], axis=1)

# %%
final_matrix
final_combined = pd.merge(left=final_matrix, right=combined, left_on=['lat', 'lon'], right_on=['latitude', 'longitude'])

# %%
final_matrix
# Out:
#      lodging  supermarket  pharmacy  park  restaurant  clothing_store  store  \
# 0         22            0         1     5          37              20     42
# 1          1            1         2     5          19               0     54
# 2         14            3         8     5          60              19     48
# 3          0            1         0     4           9               1     10
# 4          0            1         0     4           9               1      9
# ..       ...          ...       ...   ...         ...             ...    ...
# 226        0            0         0     4           3               0      3
# 227        1            0         0     1          14              20     44
# 228        0            0         0     1           3               2     31
# 229        2            1         3     1          13               5     51
# 230        1            2         0     4          17               3     41
#
# ...

# %%
# !ls station_address_data

fns = ['station_address_data/Fri_Apr_30_12-20-20_2021-geoencoded_Berkeley.csv',
       'station_address_data/Fri_Apr_30_12-20-20_2021-geoencoded_Lafayeette.csv',
       'station_address_data/Fri_Apr_30_12-20-20_2021-geoencoded_LongBeach.csv',
       'station_address_data/Fri_Apr_30_12-20-20_2021-geoencoded_Misc.csv',
       'station_address_data/Fri_Apr_30_12-20-20_2021-geoencoded_SouthSanFrancisco.csv',
      ]
combined_geoencoded = pd.DataFrame()
for f in fns:
    combined_geoencoded = pd.concat([combined_geoencoded, pd.read_csv(f)])
# Out:
# Berkeley.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_Berkeley.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_Lafayeette.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_LongBeach.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_Misc.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_SanBernadino.csv
# Fri_Apr_30_12-20-20_2021-geoencoded_SouthSanFrancisco.csv
# Fri_Apr_30_16-52-23_2021-final_stations_addr_info-missed.csv
# Fri_Apr_30_16-52-23_2021-final_stations_addr_info-new.csv
# Fri_Apr_30_16-52-23_2021-final_stations_addr_info-old.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_Berkeley.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_Lafayeette.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_LongBeach.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_Misc.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_SanBernadino.csv
# Fri_Apr_30_16-52-23_2021-geoencoded_SouthSanFrancisco.csv
# Lafayeette.csv
# Lafayette.csv
# LongBeach.csv
# Misc.csv
# SanBernadino.csv
# SouthSanFrancisco.csv
# Zcraper.csv
# full_unique_addreseses.csv
# ...

# %%
final_combined = pd.merge(left=final_matrix, right=combined_geoencoded, left_on=['lat', 'lon'], right_on=['latitude', 'longitude']).drop_duplicates('mapped_addy')

# %%
final_combined
# Out:
#      lodging  supermarket  pharmacy  park  restaurant  clothing_store  store  \
# 0         22            0         1     5          37              20     42
# 2          1            1         2     5          19               0     54
# 4          0            1         0     4           9               1     10
# 6          0            1         0     4           9               1      9
# 8          2            1         8    20          46              13     42
# ..       ...          ...       ...   ...         ...             ...    ...
# 460       12            0         1     5          60              13     45
# 463        6            0        12     5          60              19     38
# 466        4            3         3     0          60              19     36
# 469        6            1        20     6          14               2     38
# 472        0            0         0     4           3               0      3
#
# ...

# %%
f = pd.merge(f, combined_geoencoded, left_on='mapped_addy', right_on='mapped_addy')

# %%
f.groupby('')
# Out:
#          Unnamed: 0                       _id          time  \
# 0                 0  607631c1fcfd04e161e08ddd  1.618359e+09
# 1                 1  607631c1fcfd04e161e08dde  1.618359e+09
# 2                 2  607632edfcfd04e161e08e1e  1.618359e+09
# 3                 3  607632edfcfd04e161e08e1f  1.618359e+09
# 4                 4  607632f9fcfd04e161e08e2b  1.618359e+09
# ...             ...                       ...           ...
# 1456721     1456721  6088808b483c8d594d0269ec  1.619559e+09
# 1456722     1456722  6088ea09483c8d594d026bbe  1.619586e+09
# 1456723     1456723  60887be3483c8d594d026998  1.619557e+09
# 1456724     1456724  60888097483c8d594d0269ed  1.619559e+09
# 1456725     1456725  6088ea15483c8d594d026bbf  1.619586e+09
#
#                          datetime connection_type available power_kwh  \
# 0        Tue Apr 13 17:05:10 2021         CHAdeMO       3/3     50 kW
# 1        Tue Apr 13 17:05:10 2021             CCS       3/3     50 kW
# ...

# %%
station_cols = ['connection_type', 'power_kwh', 'power_kwh_num', 
              'mapped_addy', #'latitude', 'longitude',
               'available_denominator']
time_cols = ['day_of_week', 'day_of_week_num', 'month', 'date', 'hour', 'minutes',
       'seconds',]

## average all columns, while getting rid of time related columns
# drop time related columns since one station should have a single score regardless of time
# ignore charging stations that have no denominator
UR_by_stations_first_group = f.drop(time_cols, axis=1)[f['available_denominator'] != 0].groupby(by=station_cols).agg('mean').reset_index()

address_cols = ['mapped_addy']#, 'latitude', 'longitude']
UR_by_stations = UR_by_stations_first_group.groupby(address_cols).agg('sum').reset_index()
UR_by_stations.head()

UR_by_stations['availability_rate'] = UR_by_stations['available_numerator']/UR_by_stations['available_denominator']

UR_by_stations['utilization_rate'] = 1-UR_by_stations['availability_rate']

UR_by_stations['total_output_kwh'] = UR_by_stations['power_kwh_num']*UR_by_stations['utilization_rate']

UR_by_stations['utilization_numerator'] = UR_by_stations['available_denominator']*UR_by_stations['utilization_rate']

# %%
UR_by_stations
# Out:
#                                            mapped_addy  power_kwh_num  \
# 0                   1 Bush St, San Francisco, CA 94104           5.00
# 1        1 Corporate Dr, South San Francisco, CA 94080           7.20
# 2                    1 Library Ave, Millbrae, CA 94030           7.20
# 3               1 Old Bayshore Hwy, Millbrae, CA 94030           7.20
# 4                                        100 Font Blvd           7.20
# ..                                                 ...            ...
# 236                                               CA-4           7.20
# 237        Corporate Dr, South San Francisco, CA 94080           6.24
# 238                                San Bruno, CA 94066          21.60
# 239  San Francisco International Airport, San Franc...          36.00
# 240               Skyline College, San Bruno, CA 94066           7.20
#
#      available_denominator    Unnamed: 0          time  available_numerator  \
# ...

# %%
geo_util= pd.merge(left=combined_geoencoded, right=UR_by_stations,on='mapped_addy')

# %%
consolidated = pd.merge(left=geo_util, right=final_combined, on='mapped_addy')

# %%
cols_to_drop= ['Unnamed: 0_x', 'original_addy_x', 'original_addy_y', 'latitude_x',
       'longitude_x', 'latitude_y', 'longitude_y', 'Unnamed: 0', 'Unnamed: 0_y', 'time']
retained_consoliddated = consolidated.drop(cols_to_drop, axis=1)

# %%
retained_consoliddated.drop_duplicates().to_csv('data/final_station_data.csv')

# %%
retained_consoliddated.drop_duplicates()
# Out:
#                                            mapped_addy  power_kwh_num  \
# 0              6410 Overland Ave, Emeryville, CA 94608           15.2
# 3                   1025 Gilman St, Berkeley, CA 94710          103.6
# 6       2000 Powell St Suite 100, Emeryville, CA 94608           28.4
# 10                    247 E 18th St, Oakland, CA 94606            7.2
# 13            5901 Shellmound St, Emeryville, CA 94608          110.8
# ..                                                 ...            ...
# 349        800 S Airport Blvd, San Francisco, CA 94128            7.2
# 351                                San Bruno, CA 94066           21.6
# 352  1227 Linda Mar Shopping Center, Pacifica, CA 9...          100.0
# 353      1 Corporate Dr, South San Francisco, CA 94080            7.2
# 354               1625 Adrian Rd, Burlingame, CA 94010           28.5
#
#      available_denominator  available_numerator  availability_rate  \
# ...

# %%
import sklearn
sklearn.__version__
# Out:
# '0.20.3'
